# %% [markdown]
# # Install Required Packages
#
# This cell installs all necessary libraries for the ensemble approach:
# - PyTorch for deep learning
# - MONAI for medical imaging (Swin-UNETR, MedNeXt)
# - nnU-Net v2 for automatic segmentation
# - Standard ML libraries (numpy, opencv, sklearn, etc.)
#
# **Note:** Adjust CUDA version based on your GPU
# **Estimated time:** 5-10 minutes

# %%
# Install PyTorch (CUDA 11.8 - adjust for your GPU)
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118

# Install MONAI with all dependencies
# !pip install "monai[all]==1.3.0"

# Install nnU-Net v2
# !pip install nnunetv2

# Install other dependencies
# !pip install opencv-python scikit-learn pandas matplotlib seaborn tqdm
# !pip install SimpleITK nibabel pydicom albumentations
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.23.0+cu126)
# Requirement already satisfied: torchaudio in /usr/local/lib/python3.12/dist-packages (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch) (3.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch) (3.0.3)
# Collecting monai==1.3.0 (from monai[all]==1.3.0)
#   Using cached monai-1.3.0-202310121228-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.12/dist-packages (from monai==1.3.0->monai[all]==1.3.0) (2.0.2)
# Requirement already satisfied: torch>=1.9 in /usr/local/lib/python3.12/dist-packages (from monai==1.3.0->monai[all]==1.3.0) (2.8.0+cu126)
# Collecting clearml>=1.10.0rc0 (from monai[all]==1.3.0)
#   Using cached clearml-2.1.3-py2.py3-none-any.whl.metadata (17 kB)
# Collecting cucim>=23.2.0 (from monai[all]==1.3.0)
#   Using cached cucim-23.10.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (43 kB)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (0.8.1)
# Collecting fire (from monai[all]==1.3.0)
#   Using cached fire-0.7.1-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: gdown>=4.4.0 in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (5.2.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (3.15.1)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (2026.1.14)
# Collecting itk>=5.2 (from monai[all]==1.3.0)
#   Using cached itk-5.4.5-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (4.25.1)
# Collecting lmdb (from monai[all]==1.3.0)
#   Using cached lmdb-1.7.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (1.4 kB)
# Collecting lpips==0.1.4 (from monai[all]==1.3.0)
#   Using cached lpips-0.1.4-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (3.10.0)
# Collecting mlflow>=1.28.0 (from monai[all]==1.3.0)
#   Using cached mlflow-3.9.0-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (5.3.2)
# Requirement already satisfied: ninja in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (1.13.0)
# Collecting nni (from monai[all]==1.3.0)
#   Using cached nni-3.0-py3-none-manylinux1_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: nvidia-ml-py in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (12.575.51)
# Requirement already satisfied: onnx>=1.13.0 in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (1.20.1)
# Collecting openslide-python==1.1.2 (from monai[all]==1.3.0)
#   Using cached openslide_python-1.1.2-cp312-cp312-linux_x86_64.whl
# Requirement already satisfied: optuna in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (4.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (2.2.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (11.3.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (5.9.5)
# Requirement already satisfied: pydicom in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (3.0.1)
# Collecting pynrrd (from monai[all]==1.3.0)
#   Using cached pynrrd-1.1.3-py3-none-any.whl.metadata (5.4 kB)
# Collecting pytorch-ignite==0.4.11 (from monai[all]==1.3.0)
#   Using cached pytorch_ignite-0.4.11-py3-none-any.whl.metadata (28 kB)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (6.0.3)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (0.25.2)
# Requirement already satisfied: scipy>=1.7.1 in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (1.15.3)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (2.19.0)
# Collecting tensorboardX (from monai[all]==1.3.0)
#   Using cached tensorboardx-2.6.4-py3-none-any.whl.metadata (6.2 kB)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (2025.10.16)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (0.23.0+cu126)
# Requirement already satisfied: tqdm>=4.47.0 in /usr/local/lib/python3.12/dist-packages (from monai[all]==1.3.0) (4.67.1)
# Collecting transformers<4.22 (from monai[all]==1.3.0)
#   Using cached transformers-4.21.3-py3-none-any.whl.metadata (81 kB)
# Collecting zarr (from monai[all]==1.3.0)
#   Using cached zarr-3.1.5-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from pytorch-ignite==0.4.11->monai[all]==1.3.0) (26.0rc2)
# Requirement already satisfied: attrs>=18.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (25.4.0)
# Collecting furl>=2.0.0 (from clearml>=1.10.0rc0->monai[all]==1.3.0)
#   Using cached furl-2.1.4-py2.py3-none-any.whl.metadata (25 kB)
# Collecting pathlib2>=2.3.0 (from clearml>=1.10.0rc0->monai[all]==1.3.0)
#   Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: pyparsing>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (2.9.0.post0)
# Requirement already satisfied: pyjwt<2.11.0,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (2.10.1)
# Requirement already satisfied: six>=1.16.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (1.17.0)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (2.6.3)
# Requirement already satisfied: referencing<0.40 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (0.37.0)
# Requirement already satisfied: requests>=2.32.0 in /usr/local/lib/python3.12/dist-packages (from clearml>=1.10.0rc0->monai[all]==1.3.0) (2.32.5)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from cucim>=23.2.0->monai[all]==1.3.0) (8.3.1)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.12/dist-packages (from cucim>=23.2.0->monai[all]==1.3.0) (0.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown>=4.4.0->monai[all]==1.3.0) (4.13.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from gdown>=4.4.0->monai[all]==1.3.0) (3.20.3)
# Collecting itk-core==5.4.5 (from itk>=5.2->monai[all]==1.3.0)
#   Using cached itk_core-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-numerics==5.4.5 (from itk>=5.2->monai[all]==1.3.0)
#   Using cached itk_numerics-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-io==5.4.5 (from itk>=5.2->monai[all]==1.3.0)
#   Using cached itk_io-5.4.5-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-filtering==5.4.5 (from itk>=5.2->monai[all]==1.3.0)
#   Using cached itk_filtering-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-registration==5.4.5 (from itk>=5.2->monai[all]==1.3.0)
#   Using cached itk_registration-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Collecting itk-segmentation==5.4.5 (from itk>=5.2->monai[all]==1.3.0)
#   Using cached itk_segmentation-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (22 kB)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->monai[all]==1.3.0) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema->monai[all]==1.3.0) (0.27.1)
# Collecting mlflow-skinny==3.9.0 (from mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached mlflow_skinny-3.9.0-py3-none-any.whl.metadata (32 kB)
# Collecting mlflow-tracing==3.9.0 (from mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached mlflow_tracing-3.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting Flask-CORS<7 (from mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.12/dist-packages (from mlflow>=1.28.0->monai[all]==1.3.0) (3.1.2)
# Requirement already satisfied: alembic!=1.10.0,<2 in /usr/local/lib/python3.12/dist-packages (from mlflow>=1.28.0->monai[all]==1.3.0) (1.17.0)
# Requirement already satisfied: cryptography<47,>=43.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow>=1.28.0->monai[all]==1.3.0) (46.0.3)
# Requirement already satisfied: docker<8,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow>=1.28.0->monai[all]==1.3.0) (7.1.0)
# Collecting graphene<4 (from mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting huey<3,>=2.5.4 (from mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached huey-2.6.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pyarrow<23,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow>=1.28.0->monai[all]==1.3.0) (22.0.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.12/dist-packages (from mlflow>=1.28.0->monai[all]==1.3.0) (1.6.1)
# Collecting skops<1 (from mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached skops-0.13.0-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow>=1.28.0->monai[all]==1.3.0) (2.0.44)
# Requirement already satisfied: cachetools<7,>=5.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (5.5.2)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached databricks_sdk-0.85.0-py3-none-any.whl.metadata (40 kB)
# Requirement already satisfied: fastapi<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.123.10)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (3.1.45)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (8.7.0)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (1.37.0)
# Requirement already satisfied: opentelemetry-proto<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (1.37.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (1.37.0)
# Collecting packaging (from pytorch-ignite==0.4.11->monai[all]==1.3.0)
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: protobuf<7,>=3.12.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (5.29.5)
# Requirement already satisfied: pydantic<3,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (2.12.5)
# Requirement already satisfied: python-dotenv<2,>=0.19.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (1.1.1)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (4.15.0)
# Requirement already satisfied: uvicorn<1 in /usr/local/lib/python3.12/dist-packages (from mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.38.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->monai[all]==1.3.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->monai[all]==1.3.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->monai[all]==1.3.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->monai[all]==1.3.0) (1.4.9)
# Requirement already satisfied: ml_dtypes>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from onnx>=1.13.0->monai[all]==1.3.0) (0.5.3)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->monai[all]==1.3.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->monai[all]==1.3.0) (2025.2)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->monai[all]==1.3.0) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.14.2->monai[all]==1.3.0) (2.37.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (3.4.0)
# Requirement already satisfied: huggingface-hub<1.0,>=0.1.0 in /usr/local/lib/python3.12/dist-packages (from transformers<4.22->monai[all]==1.3.0) (0.36.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers<4.22->monai[all]==1.3.0) (2025.11.3)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1 (from transformers<4.22->monai[all]==1.3.0)
#   Using cached tokenizers-0.12.1.tar.gz (220 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: termcolor in /usr/local/lib/python3.12/dist-packages (from fire->monai[all]==1.3.0) (3.1.0)
# Collecting astor (from nni->monai[all]==1.3.0)
#   Using cached astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: colorama in /usr/local/lib/python3.12/dist-packages (from nni->monai[all]==1.3.0) (0.4.6)
# Collecting filelock (from gdown>=4.4.0->monai[all]==1.3.0)
#   Using cached filelock-3.11.0-py3-none-any.whl.metadata (2.5 kB)
# Collecting json-tricks>=3.15.5 (from nni->monai[all]==1.3.0)
#   Using cached json_tricks-3.17.3-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (from nni->monai[all]==1.3.0) (3.16.0)
# Collecting PythonWebHDFS (from nni->monai[all]==1.3.0)
#   Using cached PythonWebHDFS-0.2.3-py3-none-any.whl.metadata (717 bytes)
# Collecting responses (from nni->monai[all]==1.3.0)
#   Using cached responses-0.25.8-py3-none-any.whl.metadata (47 kB)
# Collecting schema (from nni->monai[all]==1.3.0)
#   Using cached schema-0.7.8-py2.py3-none-any.whl.metadata (34 kB)
# Collecting typeguard<4.1.3,>=3.0.0 (from nni->monai[all]==1.3.0)
#   Using cached typeguard-4.1.2-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: websockets>=10.1 in /usr/local/lib/python3.12/dist-packages (from nni->monai[all]==1.3.0) (15.0.1)
# Requirement already satisfied: colorlog in /usr/local/lib/python3.12/dist-packages (from optuna->monai[all]==1.3.0) (6.10.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]==1.3.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]==1.3.0) (1.75.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]==1.3.0) (3.9)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]==1.3.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard->monai[all]==1.3.0) (3.1.3)
# Collecting donfig>=0.8 (from zarr->monai[all]==1.3.0)
#   Using cached donfig-0.8.1.post1-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: google-crc32c>=1.5 in /usr/local/lib/python3.12/dist-packages (from zarr->monai[all]==1.3.0) (1.7.1)
# Collecting numcodecs>=0.14 (from zarr->monai[all]==1.3.0)
#   Using cached numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (3.4 kB)
# Requirement already satisfied: Mako in /usr/local/lib/python3.12/dist-packages (from alembic!=1.10.0,<2->mlflow>=1.28.0->monai[all]==1.3.0) (1.3.10)
# Requirement already satisfied: cffi>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from cryptography<47,>=43.0.0->mlflow>=1.28.0->monai[all]==1.3.0) (2.0.0)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow>=1.28.0->monai[all]==1.3.0) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow>=1.28.0->monai[all]==1.3.0) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from Flask<4->mlflow>=1.28.0->monai[all]==1.3.0) (3.0.3)
# Collecting orderedmultidict>=1.0.1 (from furl>=2.0.0->clearml>=1.10.0rc0->monai[all]==1.3.0)
#   Using cached orderedmultidict-1.0.2-py2.py3-none-any.whl.metadata (1.2 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached graphql_core-3.2.7-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow>=1.28.0->monai[all]==1.3.0)
#   Using cached graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers<4.22->monai[all]==1.3.0) (1.2.1rc0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml>=1.10.0rc0->monai[all]==1.3.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml>=1.10.0rc0->monai[all]==1.3.0) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.0->clearml>=1.10.0rc0->monai[all]==1.3.0) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow>=1.28.0->monai[all]==1.3.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn<2->mlflow>=1.28.0->monai[all]==1.3.0) (3.6.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable->nni->monai[all]==1.3.0) (0.2.14)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow>=1.28.0->monai[all]==1.3.0) (3.2.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=1.9->monai==1.3.0->monai[all]==1.3.0) (1.3.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown>=4.4.0->monai[all]==1.3.0) (2.8)
# Requirement already satisfied: simplejson in /usr/local/lib/python3.12/dist-packages (from PythonWebHDFS->nni->monai[all]==1.3.0) (3.20.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown>=4.4.0->monai[all]==1.3.0) (1.7.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=2.0.0->cryptography<47,>=43.0.0->mlflow>=1.28.0->monai[all]==1.3.0) (2.23)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.12/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (2.47.0)
# Requirement already satisfied: starlette<0.51.0,>=0.40.0 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.50.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from fastapi<1->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.0.4)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.12/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (3.23.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.58b0 in /usr/local/lib/python3.12/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.58b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=2.0.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.4.2)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.12/dist-packages (from uvicorn<1->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (4.9.1)
# Requirement already satisfied: anyio<5,>=3.6.2 in /usr/local/lib/python3.12/dist-packages (from starlette<0.51.0,>=0.40.0->fastapi<1->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (4.12.1)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==3.9.0->mlflow>=1.28.0->monai[all]==1.3.0) (0.6.1)
# Using cached monai-1.3.0-202310121228-py3-none-any.whl (1.3 MB)
# Using cached lpips-0.1.4-py3-none-any.whl (53 kB)
# Using cached pytorch_ignite-0.4.11-py3-none-any.whl (266 kB)
# Using cached clearml-2.1.3-py2.py3-none-any.whl (1.4 MB)
# Using cached cucim-23.10.0-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
# Using cached itk-5.4.5-cp311-abi3-manylinux_2_28_x86_64.whl (16 kB)
# Using cached itk_core-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (80.9 MB)
# Using cached itk_filtering-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (67.8 MB)
# Using cached itk_io-5.4.5-cp311-abi3-manylinux_2_28_x86_64.whl (28.0 MB)
# Using cached itk_numerics-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (57.2 MB)
# Using cached itk_registration-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (28.5 MB)
# Using cached itk_segmentation-5.4.5-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (15.9 MB)
# Using cached mlflow-3.9.0-py3-none-any.whl (9.7 MB)
# Using cached mlflow_skinny-3.9.0-py3-none-any.whl (2.8 MB)
# Using cached mlflow_tracing-3.9.0-py3-none-any.whl (1.4 MB)
# Using cached transformers-4.21.3-py3-none-any.whl (4.7 MB)
# Using cached fire-0.7.1-py3-none-any.whl (115 kB)
# Using cached lmdb-1.7.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (299 kB)
# Using cached nni-3.0-py3-none-manylinux1_x86_64.whl (61.4 MB)
# Using cached pynrrd-1.1.3-py3-none-any.whl (23 kB)
# Using cached tensorboardx-2.6.4-py3-none-any.whl (87 kB)
# Using cached zarr-3.1.5-py3-none-any.whl (284 kB)
# Using cached donfig-0.8.1.post1-py3-none-any.whl (21 kB)
# Using cached filelock-3.11.0-py3-none-any.whl (10.0 kB)
# Using cached flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Using cached furl-2.1.4-py2.py3-none-any.whl (27 kB)
# Using cached graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Using cached gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Using cached huey-2.6.0-py3-none-any.whl (76 kB)
# Using cached json_tricks-3.17.3-py2.py3-none-any.whl (27 kB)
# Using cached numcodecs-0.16.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (9.2 MB)
# Using cached packaging-25.0-py3-none-any.whl (66 kB)
# Using cached pathlib2-2.3.7.post1-py2.py3-none-any.whl (18 kB)
# Using cached skops-0.13.0-py3-none-any.whl (131 kB)
# Using cached typeguard-4.1.2-py3-none-any.whl (33 kB)
# Using cached astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Using cached PythonWebHDFS-0.2.3-py3-none-any.whl (10 kB)
# Using cached responses-0.25.8-py3-none-any.whl (34 kB)
# Using cached schema-0.7.8-py2.py3-none-any.whl (19 kB)
# Using cached databricks_sdk-0.85.0-py3-none-any.whl (796 kB)
# Using cached graphql_core-3.2.7-py3-none-any.whl (207 kB)
# Using cached graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Using cached orderedmultidict-1.0.2-py2.py3-none-any.whl (11 kB)
# Building wheels for collected packages: tokenizers
#   error: subprocess-exited-with-error
#
#   × Building wheel for tokenizers (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Building wheel for tokenizers (pyproject.toml) ... error
#   ERROR: Failed building wheel for tokenizers
# Failed to build tokenizers
# ERROR: ERROR: Failed to build installable wheels for some pyproject.toml based projects (tokenizers)
# Requirement already satisfied: nnunetv2 in /usr/local/lib/python3.12/dist-packages (2.6.4)
# Requirement already satisfied: torch!=2.9.*,>=2.1.2 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.8.0+cu126)
# Requirement already satisfied: acvl-utils<0.3,>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.2.5)
# Requirement already satisfied: dynamic-network-architectures<0.5,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.4.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (4.67.1)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (1.15.3)
# Requirement already satisfied: batchgenerators>=0.25.1 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.25.1)
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.0.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (1.6.1)
# Requirement already satisfied: scikit-image>=0.19.3 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.25.2)
# Requirement already satisfied: SimpleITK>=2.2.1 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.5.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.2.2)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.21)
# Requirement already satisfied: tifffile in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2025.10.16)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2.32.5)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (5.3.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.13.2)
# Requirement already satisfied: imagecodecs in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (2026.1.14)
# Requirement already satisfied: yacs in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.1.8)
# Requirement already satisfied: batchgeneratorsv2>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.3.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (0.8.1)
# Requirement already satisfied: blosc2>=3.0.0b1 in /usr/local/lib/python3.12/dist-packages (from nnunetv2) (3.10.2)
# Requirement already satisfied: connected-components-3d in /usr/local/lib/python3.12/dist-packages (from acvl-utils<0.3,>=0.2.3->nnunetv2) (3.26.1)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25.1->nnunetv2) (11.3.0)
# Requirement already satisfied: future in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25.1->nnunetv2) (1.0.0)
# Requirement already satisfied: unittest2 in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25.1->nnunetv2) (1.1.0)
# Requirement already satisfied: threadpoolctl in /usr/local/lib/python3.12/dist-packages (from batchgenerators>=0.25.1->nnunetv2) (3.6.0)
# Requirement already satisfied: fft-conv-pytorch in /usr/local/lib/python3.12/dist-packages (from batchgeneratorsv2>=0.3.0->nnunetv2) (1.2.0)
# Requirement already satisfied: ndindex in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (1.10.0)
# Requirement already satisfied: msgpack in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (1.1.2)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (4.5.1)
# Requirement already satisfied: numexpr>=2.14.1 in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (2.14.1)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.12/dist-packages (from blosc2>=3.0.0b1->nnunetv2) (9.0.0)
# Requirement already satisfied: timm<1.0.23 in /usr/local/lib/python3.12/dist-packages (from dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (1.0.20)
# Requirement already satisfied: networkx>=3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (3.5)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (2.37.0)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (26.0rc2)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image>=0.19.3->nnunetv2) (0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (1.13.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch!=2.9.*,>=2.1.2->nnunetv2) (3.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->nnunetv2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->nnunetv2) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->nnunetv2) (2025.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (2.6.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->nnunetv2) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->nnunetv2) (1.5.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from yacs->nnunetv2) (6.0.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->nnunetv2) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch!=2.9.*,>=2.1.2->nnunetv2) (1.3.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm<1.0.23->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (0.23.0+cu126)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from timm<1.0.23->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (0.36.0)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.12/dist-packages (from timm<1.0.23->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (0.6.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch!=2.9.*,>=2.1.2->nnunetv2) (3.0.3)
# Collecting argparse (from unittest2->batchgenerators>=0.25.1->nnunetv2)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: traceback2 in /usr/local/lib/python3.12/dist-packages (from unittest2->batchgenerators>=0.25.1->nnunetv2) (1.4.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->timm<1.0.23->dynamic-network-architectures<0.5,>=0.4.1->nnunetv2) (1.2.1rc0)
# Requirement already satisfied: linecache2 in /usr/local/lib/python3.12/dist-packages (from traceback2->unittest2->batchgenerators>=0.25.1->nnunetv2) (1.0.0)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.12.0.88)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.6.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (4.67.1)
# Requirement already satisfied: numpy<2.3.0,>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (26.0rc2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: SimpleITK in /usr/local/lib/python3.12/dist-packages (2.5.3)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (5.3.2)
# Requirement already satisfied: pydicom in /usr/local/lib/python3.12/dist-packages (3.0.1)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (2.0.8)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from nibabel) (26.0rc2)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel) (4.15.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations) (1.15.3)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.12/dist-packages (from albumentations) (6.0.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations) (2.12.5)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations) (0.0.24)
# Requirement already satisfied: opencv-python-headless>=4.9.0.80 in /usr/local/lib/python3.12/dist-packages (from albumentations) (4.12.0.88)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (4.2.1)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations) (6.5.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations) (0.4.2)

# %% [markdown]
# Import Libraries

# %%
# !pip install monai
# Out:
# Requirement already satisfied: monai in /usr/local/lib/python3.12/dist-packages (1.5.2)
# Requirement already satisfied: numpy<3.0,>=1.24 in /usr/local/lib/python3.12/dist-packages (from monai) (2.0.2)
# Requirement already satisfied: torch>=2.4.1 in /usr/local/lib/python3.12/dist-packages (from monai) (2.8.0+cu126)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.20.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (2025.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (1.11.1.6)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.4.1->monai) (3.4.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.4.1->monai) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.4.1->monai) (3.0.3)

# %% [markdown]
# # Import Required Libraries
#
# Import all necessary libraries for:
# - Deep learning (PyTorch, MONAI)
# - Data processing (numpy, opencv)
# - Visualization (matplotlib, seaborn)
# - File handling (pathlib, json)
#
# **No errors should appear if installation was successful**

# %%
# Standard libraries
import os
import sys
import json
import warnings
from pathlib import Path
from tqdm import tqdm
import shutil

# Data processing
import numpy as np
import pandas as pd
import cv2
from sklearn.model_selection import KFold

# Deep learning
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from torch.optim import Adam
from torch.optim.lr_scheduler import CosineAnnealingLR

# MONAI
from monai.networks.nets import SwinUNETR, UNet
from monai.losses import DiceLoss
from monai.metrics import DiceMetric
from monai.transforms import (
    Compose, RandRotate, RandFlip, RandZoom
)

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress warnings
warnings.filterwarnings('ignore')

print("✓ All libraries imported successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")
if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name(0)}")
# Out:
# ✓ All libraries imported successfully!
# PyTorch version: 2.8.0+cu126
# CUDA available: True
# GPU: Tesla T4

# %% [markdown]
# Set Random Seeds

# %% [markdown]
# # Set Random Seeds for Reproducibility
#
# Ensures reproducible results across multiple runs by setting:
# - Python random seed
# - NumPy random seed
# - PyTorch random seed (CPU & GPU)
#
# **Important:** Same seeds = same results

# %%
def set_seed(seed=42):
    """Set random seeds for reproducibility"""
    import random
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False
    
    print(f"✓ Random seed set to {seed}")

set_seed(42)
# Out:
# ✓ Random seed set to 42

# %% [markdown]
# # Create Project Directory Structure
#
# Creates all necessary folders for:
# - Raw data (KSSD2025 images and masks)
# - Preprocessed data (nnU-Net and MONAI formats)
# - Model checkpoints (saved weights)
# - Results (predictions, visualizations)
#
# **Run this before any training**

# %%
def create_directories():
    """Create all necessary directories"""
    
    directories = [
        # Data directories
        "data/KSSD2025/images",
        "data/KSSD2025/masks",
        "data/nnUNet_raw",
        "data/nnUNet_preprocessed",
        "data/nnUNet_results",
        "data/MONAI_data",
        
        # Results directories
        "results/nnunet",
        "results/swin_unetr",
        "results/mednext",
        "results/ensemble",
        "results/visualizations",
        
        # Model checkpoints
        "checkpoints/nnunet",
        "checkpoints/swin_unetr",
        "checkpoints/mednext",
    ]
    
    for directory in directories:
        Path(directory).mkdir(parents=True, exist_ok=True)
    
    print("✓ Directory structure created successfully!")
    print(f"  Total directories: {len(directories)}")

create_directories()
# Out:
# ✓ Directory structure created successfully!
#   Total directories: 14

# %%
import os

BASE_PATH = "/kaggle/input/kssd2025-kidney-stone-segmentation-dataset"

for root, dirs, files in os.walk(BASE_PATH):
    print(root)
    print("  Dirs:", dirs)
    print("  Files:", files[:5])
    break
# Out:
# /kaggle/input/kssd2025-kidney-stone-segmentation-dataset
#   Dirs: ['data']
#   Files: []

# %% [markdown]
# # KSSD2025 Dataset Preprocessor
#
# This class handles:
# - Creating 5-fold cross-validation splits
# - Converting data to nnU-Net format (for nnU-Net model)
# - Converting data to MONAI format (for Swin-UNETR and MedNeXt)
# - Maintaining consistent splits across all models
#
# **Key Features:**
# - Automatic fold splitting
# - Format conversion for different frameworks
# - Preserves data integrity

# %% [markdown]
# # nnU-Net Training Wrapper
#
# nnU-Net is a self-configuring framework that:
# - Automatically determines preprocessing
# - Automatically selects architecture
# - Automatically tunes hyperparameters
#
# This wrapper simplifies:
# - Environment setup
# - Training all 5 folds
# - Running predictions
# - Ensemble predictions
#
# **nnU-Net Advantages:**
# - Proven SOTA performance
# - No manual hyperparameter tuning
# - Robust to different datasets

# %%
import subprocess

class nnUNetTrainer:
    """
    Wrapper for nnU-Net v2 training
    
    nnU-Net is a self-configuring segmentation method that automatically:
    - Configures preprocessing
    - Selects network architecture  
    - Tunes hyperparameters
    
    We just need to provide the data and let it run!
    """
    
    def __init__(self, dataset_id=500, dataset_name="KSSD2025"):
        """
        Initialize nnU-Net trainer
        
        Args:
            dataset_id: Unique dataset identifier (default: 500)
            dataset_name: Dataset name (default: KSSD2025)
        """
        self.dataset_id = dataset_id
        self.dataset_name = dataset_name
        
        # Set nnU-Net environment variables
        self.setup_environment()
    
    def setup_environment(self):
        """
        Set up nnU-Net environment variables
        
        nnU-Net requires 3 paths:
        - nnUNet_raw: Raw dataset location
        - nnUNet_preprocessed: Where preprocessed data goes
        - nnUNet_results: Where trained models are saved
        """
        base_path = Path("data")
        
        os.environ['nnUNet_raw'] = str(base_path / "nnUNet_raw")
        os.environ['nnUNet_preprocessed'] = str(base_path / "nnUNet_preprocessed")
        os.environ['nnUNet_results'] = str(base_path / "nnUNet_results")
        
        print("✓ nnU-Net environment variables set:")
        print(f"  nnUNet_raw: {os.environ['nnUNet_raw']}")
        print(f"  nnUNet_preprocessed: {os.environ['nnUNet_preprocessed']}")
        print(f"  nnUNet_results: {os.environ['nnUNet_results']}")
    
    def plan_and_preprocess(self):
        """
        Run nnU-Net preprocessing pipeline
        
        This step:
        - Analyzes dataset properties
        - Determines optimal preprocessing
        - Configures network architecture
        - Prepares data for training
        
        **Run this ONCE before training**
        **Time:** ~10-20 minutes
        """
        print("\n=== nnU-Net Planning and Preprocessing ===")
        
        cmd = [
            "nnUNetv2_plan_and_preprocess",
            "-d", str(self.dataset_id),
            "--verify_dataset_integrity"
        ]
        
        print(f"Running: {' '.join(cmd)}")
        subprocess.run(cmd, check=True)
        print("✓ Preprocessing completed!")
    
    def train_fold(self, fold=0, configuration="2d", trainer="nnUNetTrainer"):
        """
        Train a single fold
        
        Args:
            fold: Fold number (0-4)
            configuration: '2d' or '3d' (use 2d for our dataset)
            trainer: nnU-Net trainer variant (default is fine)
            
        **Time per fold:** ~4-6 hours on RTX 3060
        """
        print(f"\n=== Training nnU-Net Fold {fold} ===")
        
        cmd = [
            "nnUNetv2_train",
            str(self.dataset_id),
            configuration,
            str(fold),
            "-tr", trainer,
            "--npz"  # Save probability maps
        ]
        
        print(f"Running: {' '.join(cmd)}")
        subprocess.run(cmd, check=True)
        print(f"✓ Fold {fold} training completed!")
    
    def train_all_folds(self, n_folds=5, configuration="2d"):
        """
        Train all 5 folds sequentially
        
        Args:
            n_folds: Number of folds (default: 5)
            configuration: 2d or 3d
            
        **Total time:** ~20-30 hours (let it run overnight)
        """
        print(f"\n{'='*60}")
        print(f"Training nnU-Net - All {n_folds} Folds")
        print(f"{'='*60}\n")
        
        for fold in range(n_folds):
            self.train_fold(fold=fold, configuration=configuration)
        
        print(f"\n{'='*60}")
        print("✓ All folds training completed!")
        print(f"{'='*60}\n")
    
    def predict(self, input_folder, output_folder, fold=0, configuration="2d"):
        """
        Run prediction on test data using single fold
        
        Args:
            input_folder: Folder with test images
            output_folder: Where to save predictions
            fold: Which fold's model to use
            configuration: 2d or 3d
        """
        print(f"\n=== Running Prediction (Fold {fold}) ===")
        
        cmd = [
            "nnUNetv2_predict",
            "-i", str(input_folder),
            "-o", str(output_folder),
            "-d", str(self.dataset_id),
            "-c", configuration,
            "-f", str(fold),
            "--save_probabilities"
        ]
        
        print(f"Running: {' '.join(cmd)}")
        subprocess.run(cmd, check=True)
        print("✓ Prediction completed!")
    
    def predict_ensemble(self, input_folder, output_folder, 
                        n_folds=5, configuration="2d"):
        """
        Run ensemble prediction across all folds
        
        nnU-Net automatically averages predictions from all folds
        
        Args:
            input_folder: Folder with test images
            output_folder: Where to save predictions
            n_folds: Number of folds to ensemble
            configuration: 2d or 3d
        """
        print(f"\n=== Running nnU-Net Ensemble Prediction ===")
        
        fold_str = " ".join([str(i) for i in range(n_folds)])
        
        cmd = [
            "nnUNetv2_predict",
            "-i", str(input_folder),
            "-o", str(output_folder),
            "-d", str(self.dataset_id),
            "-c", configuration,
            "-f", fold_str,
            "--save_probabilities"
        ]
        
        print(f"Running: {' '.join(cmd)}")
        subprocess.run(cmd, check=True)
        print("✓ Ensemble prediction completed!")

print("✓ nnUNetTrainer class defined")
# Out:
# ✓ nnUNetTrainer class defined

# %%
import os
import json
import shutil
from pathlib import Path
from sklearn.model_selection import KFold
import numpy as np
import subprocess

# =========================================================
# PART 1: PREPROCESSING
# =========================================================

class KSSD2025Preprocessor:
    def __init__(self, raw_data_path, output_base_path, n_folds=5):
        self.raw_path = Path(raw_data_path)
        self.output_path = Path(output_base_path)
        self.n_folds = n_folds
        
        self.nnunet_path = self.output_path / "nnUNet_raw"
        self.monai_path = self.output_path / "MONAI_data"
        
        self.images = None
        self.masks = None
        
        print(f"✓ Preprocessor initialized")
        print(f"  Raw data: {self.raw_path}")
    
    def _find_images_and_masks(self):
        if self.images is not None and self.masks is not None:
            return self.images, self.masks
            
        img_dir = self.raw_path / "image"
        mask_dir = self.raw_path / "label"
        
        print(f"\n=== Searching for images and masks ===")
        print(f"Image dir: {img_dir}")
        print(f"Mask dir: {mask_dir}")
        
        # .tif files (YOUR dataset format)
        self.images = sorted(list(img_dir.glob("*.tif")))
        self.masks = sorted(list(mask_dir.glob("*.tif")))
        
        print(f"✓ Found {len(self.images)} images and {len(self.masks)} masks")
        
        if len(self.images) == 0:
            raise ValueError(f"No images found in {img_dir}")
        
        return self.images, self.masks
    
    def prepare_nnunet_format(self, dataset_id=500, dataset_name="KSSD2025"):
        print("\n=== Preparing nnU-Net Format ===")
        
        images, masks = self._find_images_and_masks()
        
        dataset_folder = self.nnunet_path / f"Dataset{dataset_id:03d}_{dataset_name}"
        imagesTr = dataset_folder / "imagesTr"
        labelsTr = dataset_folder / "labelsTr"
        
        if dataset_folder.exists():
            print(f"Removing existing dataset...")
            shutil.rmtree(dataset_folder)
        
        imagesTr.mkdir(parents=True, exist_ok=True)
        labelsTr.mkdir(parents=True, exist_ok=True)
        
        print(f"Converting {len(images)} files...")
        
        for idx, (img_path, mask_path) in enumerate(zip(images, masks)):
            case_id = f"{dataset_name}_{idx:04d}"
            shutil.copy(img_path, imagesTr / f"{case_id}_0000.tif")
            shutil.copy(mask_path, labelsTr / f"{case_id}.tif")
            
            if (idx + 1) % 200 == 0:
                print(f"  {idx + 1}/{len(images)} done")
        
        print(f"✓ All {len(images)} files copied")
        
        # nnU-Net v2 dataset.json
        dataset_json = {
            "channel_names": {"0": "grayscale"},
            "labels": {"background": 0, "kidney_stone": 1},
            "numTraining": len(images),
            "file_ending": ".tif",
            "overwrite_image_reader_writer": "NaturalImage2DIO"
        }
        
        with open(dataset_folder / "dataset.json", "w") as f:
            json.dump(dataset_json, f, indent=4)
        
        print(f"✓ dataset.json created")
        return dataset_folder
    
    def prepare_monai_format(self):
        print("\n=== Preparing MONAI Format ===")
        
        images, masks = self._find_images_and_masks()
        
        if len(images) == 0:
            raise ValueError("No images for MONAI!")
        
        self.monai_path.mkdir(parents=True, exist_ok=True)
        
        kfold = KFold(n_splits=self.n_folds, shuffle=True, random_state=42)
        indices = np.arange(len(images))
        
        fold_splits = {}
        for fold, (train_idx, val_idx) in enumerate(kfold.split(indices)):
            fold_splits[f"fold_{fold}"] = {"train": [], "val": []}
            
            for idx in train_idx:
                fold_splits[f"fold_{fold}"]["train"].append({
                    "image": str(images[idx]),
                    "label": str(masks[idx])
                })
            
            for idx in val_idx:
                fold_splits[f"fold_{fold}"]["val"].append({
                    "image": str(images[idx]),
                    "label": str(masks[idx])
                })
            
            print(f"  Fold {fold}: {len(train_idx)} train, {len(val_idx)} val")
        
        with open(self.monai_path / "fold_splits.json", "w") as f:
            json.dump(fold_splits, f, indent=4)
        
        print(f"✓ MONAI ready: {self.n_folds} folds")
        return self.monai_path

# =========================================================
# PART 2: nnU-Net TRAINER
# =========================================================

class nnUNetTrainer:
    def __init__(self, dataset_id=500, dataset_name="KSSD2025", base_path="/kaggle/working"):
        self.dataset_id = dataset_id
        self.dataset_name = dataset_name
        self.base_path = Path(base_path)
        
        self.nnunet_raw = self.base_path / "nnUNet_raw"
        self.nnunet_preprocessed = self.base_path / "nnUNet_preprocessed"
        self.nnunet_results = self.base_path / "nnUNet_results"
        
        self.nnunet_preprocessed.mkdir(parents=True, exist_ok=True)
        self.nnunet_results.mkdir(parents=True, exist_ok=True)
        
        os.environ['nnUNet_raw'] = str(self.nnunet_raw)
        os.environ['nnUNet_preprocessed'] = str(self.nnunet_preprocessed)
        os.environ['nnUNet_results'] = str(self.nnunet_results)
        
        print(f"✓ nnU-Net environment set")
    
    def plan_and_preprocess(self):
        print(f"\n=== nnU-Net Planning and Preprocessing ===")
        
        # IMPORTANT: NO --verify_dataset_integrity flag
        cmd = ["nnUNetv2_plan_and_preprocess", "-d", str(self.dataset_id)]
        
        print(f"Running: {' '.join(cmd)}")
        print("⏳ This takes 5-15 minutes...")
        subprocess.run(cmd, check=True)
        print("✓ Preprocessing done!")
    
    def train_fold(self, fold=0, configuration="2d"):
        print(f"\n=== Training Fold {fold} ===")
        cmd = ["nnUNetv2_train", str(self.dataset_id), configuration, str(fold)]
        print(f"Running: {' '.join(cmd)}")
        subprocess.run(cmd, check=True)
        print(f"✓ Fold {fold} done!")
    
    def train_all_folds(self, n_folds=5, configuration="2d"):
        print(f"\n{'='*60}")
        print(f"⚠️  Training {n_folds} folds (24-48 hours!)")
        print(f"{'='*60}\n")
        
        for fold in range(n_folds):
            self.train_fold(fold, configuration)
        
        print(f"\n✓ All {n_folds} folds trained!")

# =========================================================
# RUN EVERYTHING
# =========================================================

print("="*60)
print("PREPROCESSING")
print("="*60)

preprocessor = KSSD2025Preprocessor(
    raw_data_path="/kaggle/input/kssd2025-kidney-stone-segmentation-dataset/data",
    output_base_path="/kaggle/working",
    n_folds=5
)

nnunet_folder = preprocessor.prepare_nnunet_format(dataset_id=500, dataset_name="KSSD2025")
monai_folder = preprocessor.prepare_monai_format()

print("\n" + "="*60)
print("nnU-Net SETUP")
print("="*60)

nnunet_trainer = nnUNetTrainer(dataset_id=500, base_path="/kaggle/working")
nnunet_trainer.plan_and_preprocess()

print("\n" + "="*60)
print("✓✓✓ SETUP COMPLETE! ✓✓✓")
print("="*60)
print(f"nnU-Net: {nnunet_folder}")
print(f"MONAI: {monai_folder}")
print(f"Samples: 838 (.tif files)")
print("\nTo train (24-48 hrs):")
print("  nnunet_trainer.train_all_folds(n_folds=5)")
print("="*60)
# Out:
# ============================================================
# PREPROCESSING
# ============================================================
# ✓ Preprocessor initialized
#   Raw data: /kaggle/input/kssd2025-kidney-stone-segmentation-dataset/data
#
# === Preparing nnU-Net Format ===
#
# === Searching for images and masks ===
# Image dir: /kaggle/input/kssd2025-kidney-stone-segmentation-dataset/data/image
# Mask dir: /kaggle/input/kssd2025-kidney-stone-segmentation-dataset/data/label
# ✓ Found 838 images and 838 masks
# Removing existing dataset...
# Converting 838 files...
#   200/838 done
#   400/838 done
#   600/838 done
#   800/838 done
# ✓ All 838 files copied
# ✓ dataset.json created
#
# === Preparing MONAI Format ===
#   Fold 0: 670 train, 168 val
#   Fold 1: 670 train, 168 val
#   Fold 2: 670 train, 168 val
#   Fold 3: 671 train, 167 val
#   Fold 4: 671 train, 167 val
# ✓ MONAI ready: 5 folds
#
# ============================================================
# nnU-Net SETUP
# ============================================================
# ✓ nnU-Net environment set
#
# === nnU-Net Planning and Preprocessing ===
# Running: nnUNetv2_plan_and_preprocess -d 500
# ⏳ This takes 5-15 minutes...
# Fingerprint extraction...
# Dataset500_KSSD2025
# Experiment planning...
#
# ############################
# INFO: You are using the old nnU-Net default planner. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# 2D U-Net configuration:
# {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 14, 'patch_size': (np.int64(448), np.int64(512)), 'median_image_size_in_voxels': array([416., 512.]), 'spacing': array([1., 1.]), 'normalization_schemes': ['ZScoreNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 7, 'features_per_stage': (32, 64, 128, 256, 512, 512, 512), 'conv_op': 'torch.nn.modules.conv.Conv2d', 'kernel_sizes': ((3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3), (3, 3)), 'strides': ((1, 1), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2), (2, 2)), 'n_conv_per_stage': (2, 2, 2, 2, 2, 2, 2), 'n_conv_per_stage_decoder': (2, 2, 2, 2, 2, 2), 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm2d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ('conv_op', 'norm_op', 'dropout_op', 'nonlin')}, 'batch_dice': True}
#
# Using <class 'nnunetv2.imageio.natural_image_reader_writer.NaturalImage2DIO'> reader/writer
# Plans were saved to /kaggle/working/nnUNet_preprocessed/Dataset500_KSSD2025/nnUNetPlans.json
# Preprocessing...
# Preprocessing dataset Dataset500_KSSD2025
# Configuration: 2d...
# 100%|██████████| 838/838 [01:31<00:00,  9.18it/s]
# Configuration: 3d_fullres...
# INFO: Configuration 3d_fullres not found in plans file nnUNetPlans.json of dataset Dataset500_KSSD2025. Skipping.
# Configuration: 3d_lowres...
# INFO: Configuration 3d_lowres not found in plans file nnUNetPlans.json of dataset Dataset500_KSSD2025. Skipping.
# ✓ Preprocessing done!
#
# ============================================================
# ✓✓✓ SETUP COMPLETE! ✓✓✓
# ============================================================
# nnU-Net: /kaggle/working/nnUNet_raw/Dataset500_KSSD2025
# MONAI: /kaggle/working/MONAI_data
# Samples: 838 (.tif files)
#
# To train (24-48 hrs):
#   nnunet_trainer.train_all_folds(n_folds=5)
# ============================================================

# %% [markdown]
# training

# %%
# Train all 5 folds
# ⚠️ WARNING: This takes 24-48 hours!
nnunet_trainer.train_all_folds(n_folds=5, configuration="2d")

print("\n" + "="*60)
print("✓ nnU-Net training completed!")
print("  Check results in: /kaggle/working/nnUNet_results/")
print("="*60)
# Out:
# ============================================================
# ⚠️  Training 5 folds (24-48 hours!)
# ============================================================
#
#
# === Training Fold 0 ===
# Running: nnUNetv2_train 500 2d 0
#
# ############################
# INFO: You are using the old nnU-Net default plans. We have updated our recommendations. Please consider using those instead! Read more here: https://github.com/MIC-DKFZ/nnUNet/blob/master/documentation/resenc_presets.md
# ############################
#
# Using device: cuda:0
#
# #######################################################################
# Please cite the following paper when using nnU-Net:
# Isensee, F., Jaeger, P. F., Kohl, S. A., Petersen, J., & Maier-Hein, K. H. (2021). nnU-Net: a self-configuring method for deep learning-based biomedical image segmentation. Nature methods, 18(2), 203-211.
# #######################################################################
#
# 2026-02-07 21:10:00.857970: Using torch.compile...
# 2026-02-07 21:10:04.468783: do_dummy_2d_data_aug: False
# 2026-02-07 21:10:04.473538: Creating new 5-fold cross-validation split...
# 2026-02-07 21:10:04.480988: Desired fold for training: 0
# 2026-02-07 21:10:04.481087: This split has 670 training and 168 validation cases.
# /usr/local/lib/python3.12/dist-packages/fft_conv_pytorch/fft_conv.py:139: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   output = output[crop_slices].contiguous()
# /usr/local/lib/python3.12/dist-packages/fft_conv_pytorch/fft_conv.py:139: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   output = output[crop_slices].contiguous()
# /usr/local/lib/python3.12/dist-packages/fft_conv_pytorch/fft_conv.py:139: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   output = output[crop_slices].contiguous()
# /usr/local/lib/python3.12/dist-packages/fft_conv_pytorch/fft_conv.py:139: UserWarning: Using a non-tuple sequence for multidimensional indexing is deprecated and will be changed in pytorch 2.9; use x[tuple(seq)] instead of x[seq]. In pytorch 2.9 this will be interpreted as tensor index, x[torch.tensor(seq)], which will result either in an error or a different result (Triggered internally at /pytorch/torch/csrc/autograd/python_variable_indexing.cpp:306.)
#   output = output[crop_slices].contiguous()
# using pin_memory on device 0
# W0207 21:10:19.886000 14686 torch/_inductor/utils.py:1436] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.12/dist-packages/torch/_inductor/lowering.py:7095: UserWarning:
# Online softmax is disabled on the fly since Inductor decides to
# split the reduction. Cut an issue to PyTorch if this is an
# important use case and you want to speed it up with online
# softmax.
#
#   warnings.warn(
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [332,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [332,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1420,0,0], thread: [102,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1420,0,0], thread: [103,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1257,0,0], thread: [48,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1478,0,0], thread: [0,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [332,0,0], thread: [42,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [332,0,0], thread: [43,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1227,0,0], thread: [48,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1135,0,0], thread: [81,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1135,0,0], thread: [18,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [600,0,0], thread: [88,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [600,0,0], thread: [89,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [570,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [570,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [570,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [570,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1523,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [571,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [571,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [17,0,0], thread: [23,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [571,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [571,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [618,0,0], thread: [40,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1050,0,0], thread: [80,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1430,0,0], thread: [102,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1174,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1240,0,0], thread: [18,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1240,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1240,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1240,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1257,0,0], thread: [112,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1241,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1241,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [593,0,0], thread: [105,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1180,0,0], thread: [14,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1137,0,0], thread: [25,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1520,0,0], thread: [82,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1425,0,0], thread: [102,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1425,0,0], thread: [103,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1241,0,0], thread: [18,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1241,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1241,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [918,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [310,0,0], thread: [31,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1238,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1238,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1238,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [18,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1428,0,0], thread: [38,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1428,0,0], thread: [39,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1886,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [694,0,0], thread: [126,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [694,0,0], thread: [127,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [616,0,0], thread: [40,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [17,0,0], thread: [86,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [313,0,0], thread: [96,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1884,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1495,0,0], thread: [16,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [788,0,0], thread: [100,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [788,0,0], thread: [101,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1139,0,0], thread: [78,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1139,0,0], thread: [79,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1224,0,0], thread: [111,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1224,0,0], thread: [112,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [795,0,0], thread: [100,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [795,0,0], thread: [101,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1139,0,0], thread: [15,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1139,0,0], thread: [16,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [795,0,0], thread: [37,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [311,0,0], thread: [95,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [693,0,0], thread: [127,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [316,0,0], thread: [96,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [314,0,0], thread: [96,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1884,0,0], thread: [41,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [312,0,0], thread: [31,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [695,0,0], thread: [127,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [695,0,0], thread: [63,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [635,0,0], thread: [35,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1424,0,0], thread: [39,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1424,0,0], thread: [103,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [636,0,0], thread: [99,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1463,0,0], thread: [0,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [790,0,0], thread: [101,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1835,0,0], thread: [100,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1835,0,0], thread: [101,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [579,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [579,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [574,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [574,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [574,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1226,0,0], thread: [112,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [577,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [577,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [577,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [635,0,0], thread: [99,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [635,0,0], thread: [100,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1421,0,0], thread: [38,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1421,0,0], thread: [102,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [568,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [568,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [568,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [568,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [577,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [577,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [577,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1029,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1029,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [108,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [109,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [808,0,0], thread: [23,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [808,0,0], thread: [24,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [108,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [109,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [42,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [43,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [44,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [117,0,0], thread: [45,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [42,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [43,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [44,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [115,0,0], thread: [45,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [694,0,0], thread: [63,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [579,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1228,0,0], thread: [48,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1519,0,0], thread: [82,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1477,0,0], thread: [64,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [119,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [119,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [119,0,0], thread: [108,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [119,0,0], thread: [109,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1837,0,0], thread: [36,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1837,0,0], thread: [37,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [121,0,0], thread: [108,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [121,0,0], thread: [109,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1836,0,0], thread: [101,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1028,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1028,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1836,0,0], thread: [37,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [578,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [578,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [578,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [572,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [572,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [572,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [572,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [572,0,0], thread: [86,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1225,0,0], thread: [48,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1225,0,0], thread: [112,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1496,0,0], thread: [17,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1028,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1028,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [567,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1138,0,0], thread: [14,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1138,0,0], thread: [16,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1032,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1032,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [578,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [578,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [578,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1032,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1032,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1061,0,0], thread: [15,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [334,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [334,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1176,0,0], thread: [18,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1176,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1524,0,0], thread: [19,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [810,0,0], thread: [87,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [810,0,0], thread: [88,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [790,0,0], thread: [37,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [789,0,0], thread: [37,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1883,0,0], thread: [41,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1883,0,0], thread: [42,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2152,0,0], thread: [23,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2152,0,0], thread: [24,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2152,0,0], thread: [25,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2152,0,0], thread: [26,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2154,0,0], thread: [24,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2154,0,0], thread: [25,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2154,0,0], thread: [26,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2144,0,0], thread: [23,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2144,0,0], thread: [24,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2144,0,0], thread: [25,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2144,0,0], thread: [26,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2144,0,0], thread: [27,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [791,0,0], thread: [101,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [805,0,0], thread: [87,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [805,0,0], thread: [88,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [808,0,0], thread: [87,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [808,0,0], thread: [88,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1423,0,0], thread: [38,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1423,0,0], thread: [39,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [120,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [120,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [120,0,0], thread: [108,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1142,0,0], thread: [13,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [118,0,0], thread: [43,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [118,0,0], thread: [44,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [118,0,0], thread: [45,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [118,0,0], thread: [106,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [118,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [118,0,0], thread: [108,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [118,0,0], thread: [109,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2154,0,0], thread: [87,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2154,0,0], thread: [89,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2154,0,0], thread: [90,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1181,0,0], thread: [78,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1026,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1026,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1181,0,0], thread: [14,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2149,0,0], thread: [22,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2149,0,0], thread: [23,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2149,0,0], thread: [24,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2149,0,0], thread: [25,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2149,0,0], thread: [26,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [2149,0,0], thread: [27,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1026,0,0], thread: [20,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1026,0,0], thread: [21,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1423,0,0], thread: [102,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1423,0,0], thread: [103,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [330,0,0], thread: [107,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1238,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1238,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1238,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [82,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [83,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [84,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1239,0,0], thread: [85,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# /tmp/torchinductor_root/4b/c4bn6mzsaechnaq3f33zbt5wcpz6imzscruterv2mselskedgufv.py:28: unknown: block: [1230,0,0], thread: [76,0,0] Assertion `index out of bounds: 0 <= tmp1 < 2` failed.
# ...
# Traceback (most recent call last):
#   File "/usr/local/bin/nnUNetv2_train", line 8, in <module>
#     sys.exit(run_training_entry())
#              ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/run/run_training.py", line 266, in run_training_entry
#     run_training(args.dataset_name_or_id, args.configuration, args.fold, args.tr, args.p, args.pretrained_weights,
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/run/run_training.py", line 207, in run_training
#     nnunet_trainer.run_training()
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/training/nnUNetTrainer/nnUNetTrainer.py", line 1375, in run_training
#     train_outputs.append(self.train_step(next(self.dataloader_train)))
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/training/nnUNetTrainer/nnUNetTrainer.py", line 991, in train_step
#     l = self.loss(output, target)
#         ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/training/loss/deep_supervision.py", line 29, in forward
#     return sum([weights[i] * self.loss(*inputs) for i, inputs in enumerate(zip(*args)) if weights[i] != 0.0])
#                              ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/training/loss/compound_losses.py", line 50, in forward
#     dc_loss = self.dc(net_output, target_dice, loss_mask=mask) \
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 375, in __call__
#     return super().__call__(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 736, in compile_wrapper
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1773, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1784, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/nnunetv2/training/loss/dice.py", line 72, in forward
#     def forward(self, x, y, loss_mask=None):
#   File "/usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py", line 929, in _fn
#     return fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/aot_autograd.py", line 1241, in forward
#     return compiled_fn(full_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 370, in runtime_wrapper
#     all_outs = call_func_at_runtime_with_args(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/utils.py", line 126, in call_func_at_runtime_with_args
#     out = normalize_as_list(f(args))
#                             ^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/utils.py", line 100, in g
#     return f(*args)
#            ^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/autograd/function.py", line 576, in apply
#     return super().apply(*args, **kwargs)  # type: ignore[misc]
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 2074, in forward
#     fw_outs = call_func_at_runtime_with_args(
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/utils.py", line 126, in call_func_at_runtime_with_args
#     out = normalize_as_list(f(args))
#                             ^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 556, in wrapper
#     return compiled_fn(runtime_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_functorch/_aot_autograd/runtime_wrappers.py", line 750, in inner_fn
#     outs = compiled_fn(args)
#            ^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/output_code.py", line 584, in __call__
#     return self.current_callable(inputs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/utils.py", line 2716, in run
#     out = model(new_inputs)
#           ^^^^^^^^^^^^^^^^^
#   File "/tmp/torchinductor_root/qr/cqrf6wpc5h2iesnaxfo5kplao7xlddg3h7ktmxm4jrthvqcl3uvk.py", line 349, in call
#     triton_poi_fused__to_copy_scatter_1.run(primals_2, buf1, 3211264, stream=stream0)
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/runtime/triton_heuristics.py", line 1133, in run
#     self.autotune_to_one_config(*args, **kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/runtime/triton_heuristics.py", line 960, in autotune_to_one_config
#     timings = self.benchmark_all_configs(*args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/runtime/triton_heuristics.py", line 935, in benchmark_all_configs
#     launcher: self.bench(launcher, *args, **kwargs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/runtime/triton_heuristics.py", line 804, in bench
#     return benchmarker.benchmark_gpu(kernel_call, rep=40)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/runtime/benchmarking.py", line 39, in wrapper
#     return fn(self, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/_inductor/runtime/benchmarking.py", line 244, in benchmark_gpu
#     torch.cuda.synchronize()
#   File "/usr/local/lib/python3.12/dist-packages/torch/cuda/__init__.py", line 1085, in synchronize
#     return torch._C._cuda_synchronize()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# torch.AcceleratorError: CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
# using pin_memory on device 0
#
# This is the configuration used by this training:
# Configuration name: 2d
#  {'data_identifier': 'nnUNetPlans_2d', 'preprocessor_name': 'DefaultPreprocessor', 'batch_size': 14, 'patch_size': [448, 512], 'median_image_size_in_voxels': [416.0, 512.0], 'spacing': [1.0, 1.0], 'normalization_schemes': ['ZScoreNormalization'], 'use_mask_for_norm': [False], 'resampling_fn_data': 'resample_data_or_seg_to_shape', 'resampling_fn_seg': 'resample_data_or_seg_to_shape', 'resampling_fn_data_kwargs': {'is_seg': False, 'order': 3, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_seg_kwargs': {'is_seg': True, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'resampling_fn_probabilities': 'resample_data_or_seg_to_shape', 'resampling_fn_probabilities_kwargs': {'is_seg': False, 'order': 1, 'order_z': 0, 'force_separate_z': None}, 'architecture': {'network_class_name': 'dynamic_network_architectures.architectures.unet.PlainConvUNet', 'arch_kwargs': {'n_stages': 7, 'features_per_stage': [32, 64, 128, 256, 512, 512, 512], 'conv_op': 'torch.nn.modules.conv.Conv2d', 'kernel_sizes': [[3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3], [3, 3]], 'strides': [[1, 1], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2], [2, 2]], 'n_conv_per_stage': [2, 2, 2, 2, 2, 2, 2], 'n_conv_per_stage_decoder': [2, 2, 2, 2, 2, 2], 'conv_bias': True, 'norm_op': 'torch.nn.modules.instancenorm.InstanceNorm2d', 'norm_op_kwargs': {'eps': 1e-05, 'affine': True}, 'dropout_op': None, 'dropout_op_kwargs': None, 'nonlin': 'torch.nn.LeakyReLU', 'nonlin_kwargs': {'inplace': True}}, '_kw_requires_import': ['conv_op', 'norm_op', 'dropout_op', 'nonlin']}, 'batch_dice': True}
#
# These are the global plan.json settings:
#  {'dataset_name': 'Dataset500_KSSD2025', 'plans_name': 'nnUNetPlans', 'original_median_spacing_after_transp': [999.0, 1.0, 1.0], 'original_median_shape_after_transp': [1, 416, 512], 'image_reader_writer': 'NaturalImage2DIO', 'transpose_forward': [0, 1, 2], 'transpose_backward': [0, 1, 2], 'experiment_planner_used': 'ExperimentPlanner', 'label_manager': 'LabelManager', 'foreground_intensity_properties_per_channel': {'0': {'max': 255.0, 'mean': 133.63563537597656, 'median': 120.0, 'min': 0.0, 'percentile_00_5': 0.0, 'percentile_99_5': 255.0, 'std': 92.86692810058594}}}
#
# 2026-02-07 21:10:07.413253: Unable to plot network architecture: nnUNet_compile is enabled!
# 2026-02-07 21:10:07.447311:
# 2026-02-07 21:10:07.450263: Epoch 0
# 2026-02-07 21:10:07.453439: Current learning rate: 0.01
# Exception in thread Thread-3 (results_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/batchgenerators/dataloading/nondet_multi_threaded_augmenter.py", line 125, in results_loop
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/batchgenerators/dataloading/nondet_multi_threaded_augmenter.py", line 103, in results_loop
#     raise RuntimeError("One or more background workers are no longer alive. Exiting. Please check the "
# RuntimeError: One or more background workers are no longer alive. Exiting. Please check the print statements above for the actual error message
# Exception in thread Thread-2 (results_loop):
# Traceback (most recent call last):
#   File "/usr/lib/python3.12/threading.py", line 1075, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.12/threading.py", line 1012, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.12/dist-packages/batchgenerators/dataloading/nondet_multi_threaded_augmenter.py", line 125, in results_loop
#     raise e
#   File "/usr/local/lib/python3.12/dist-packages/batchgenerators/dataloading/nondet_multi_threaded_augmenter.py", line 103, in results_loop
#     raise RuntimeError("One or more background workers are no longer alive. Exiting. Please check the "
# RuntimeError: One or more background workers are no longer alive. Exiting. Please check the print statements above for the actual error message
# terminate called after throwing an instance of 'c10::AcceleratorError'
#   what():  CUDA error: device-side assert triggered
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
# Exception raised from c10_cuda_check_implementation at /pytorch/c10/cuda/CUDAException.cpp:42 (most recent call first):
# frame #0: c10::Error::Error(c10::SourceLocation, std::__cxx11::basic_string<char, std::char_traits<char>, std::allocator<char> >) + 0x80 (0x7e1db4ad9eb0 in /usr/local/lib/python3.12/dist-packages/torch/lib/libc10.so)
# frame #1: <unknown function> + 0x111c7 (0x7e1db4b6c1c7 in /usr/local/lib/python3.12/dist-packages/torch/lib/libc10_cuda.so)
# frame #2: <unknown function> + 0x115da99 (0x7e1d5f95fa99 in /usr/local/lib/python3.12/dist-packages/torch/lib/libtorch_cuda.so)
# frame #3: <unknown function> + 0x11589e3 (0x7e1d5f95a9e3 in /usr/local/lib/python3.12/dist-packages/torch/lib/libtorch_cuda.so)
# frame #4: <unknown function> + 0x115f91c (0x7e1d5f96191c in /usr/local/lib/python3.12/dist-packages/torch/lib/libtorch_cuda.so)
# frame #5: <unknown function> + 0x434a5f (0x7e1dac5a0a5f in /usr/local/lib/python3.12/dist-packages/torch/lib/libtorch_python.so)
# frame #6: c10::TensorImpl::~TensorImpl() + 0x9 (0x7e1db4ab7179 in /usr/local/lib/python3.12/dist-packages/torch/lib/libc10.so)
# frame #7: <unknown function> + 0x6c9e58 (0x7e1dac835e58 in /usr/local/lib/python3.12/dist-packages/torch/lib/libtorch_python.so)
# frame #8: <unknown function> + 0x6ca22d (0x7e1dac83622d in /usr/local/lib/python3.12/dist-packages/torch/lib/libtorch_python.so)
# frame #9: /usr/bin/python3() [0x53e034]
# frame #10: /usr/bin/python3() [0x57f256]
# frame #11: /usr/bin/python3() [0x57e276]
# frame #12: /usr/bin/python3() [0x57e26f]
# frame #13: /usr/bin/python3() [0x57e26f]
# frame #14: /usr/bin/python3() [0x57e26f]
# frame #15: /usr/bin/python3() [0x57e26f]
# frame #16: /usr/bin/python3() [0x5332c9]
# frame #17: PyDict_SetItemString + 0x4e (0x619a0e in /usr/bin/python3)
# frame #18: /usr/bin/python3() [0x65be75]
# frame #19: /usr/bin/python3() [0x65beec]
# frame #20: Py_FinalizeEx + 0x16c (0x6427cc in /usr/bin/python3)
# frame #21: Py_RunMain + 0x24c (0x6504dc in /usr/bin/python3)
# frame #22: Py_BytesMain + 0x2d (0x60962d in /usr/bin/python3)
# frame #23: <unknown function> + 0x29d90 (0x7e1db5c3bd90 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #24: __libc_start_main + 0x80 (0x7e1db5c3be40 in /lib/x86_64-linux-gnu/libc.so.6)
# frame #25: _start + 0x25 (0x6094a5 in /usr/bin/python3)
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# /tmp/ipykernel_55/3978600721.py in <cell line: 0>()
#       1 # Train all 5 folds
#       2 # ⚠️ WARNING: This takes 24-48 hours!
# ----> 3 nnunet_trainer.train_all_folds(n_folds=5, configuration="2d")
#       4
#       5 print("\n" + "="*60)
#
# /tmp/ipykernel_55/2082594751.py in train_all_folds(self, n_folds, configuration)
#     175
#     176         for fold in range(n_folds):
# --> 177             self.train_fold(fold, configuration)
#     178
#     179         print(f"\n✓ All {n_folds} folds trained!")
#
# /tmp/ipykernel_55/2082594751.py in train_fold(self, fold, configuration)
#     166         cmd = ["nnUNetv2_train", str(self.dataset_id), configuration, str(fold)]
#     167         print(f"Running: {' '.join(cmd)}")
# --> 168         subprocess.run(cmd, check=True)
#     169         print(f"✓ Fold {fold} done!")
#     170
#
# /usr/lib/python3.12/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     569         retcode = process.poll()
#     570         if check and retcode:
# --> 571             raise CalledProcessError(retcode, process.args,
#     572                                      output=stdout, stderr=stderr)
#     573     return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['nnUNetv2_train', '500', '2d', '0']' died with <Signals.SIGABRT: 6>.
