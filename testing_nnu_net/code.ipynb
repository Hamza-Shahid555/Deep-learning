# %% [markdown]
# # Kidney Stone Segmentation (KSSD2025)
# ### Step 1: Dataset Loading & Preprocessing (Google Colab)
#
# This notebook prepares the KSSD2025 dataset for training
# U-Net–based deep learning models.

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

# %%
# CHANGE this path according to where your dataset exists
DATASET_ROOT = "/content/drive/MyDrive/KSSD2025"

IMAGE_DIR = f"{DATASET_ROOT}/images"
MASK_DIR  = f"{DATASET_ROOT}/masks"

print("Image folder:", IMAGE_DIR)
print("Mask folder:", MASK_DIR)
# Out:
# Image folder: /content/drive/MyDrive/KSSD2025/images
# Mask folder: /content/drive/MyDrive/KSSD2025/masks

# %%
import zipfile
import os

zip_path = r"E:\\Kidney_reasearch.zip"
extract_path = r"E:\Kidney_reasearch\unzipped_data"

# Create folder if not exists
os.makedirs(extract_path, exist_ok=True)

# Unzip
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("✅ File unzipped successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-2124743960.py in <cell line: 0>()
#       9
#      10 # Unzip
# ---> 11 with zipfile.ZipFile(zip_path, 'r') as zip_ref:
#      12     zip_ref.extractall(extract_path)
#      13
#
# /usr/lib/python3.12/zipfile/__init__.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1350             while True:
#    1351                 try:
# -> 1352                     self.fp = io.open(file, filemode)
#    1353                 except OSError:
#    1354                     if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'E:\\\\Kidney_reasearch.zip'
